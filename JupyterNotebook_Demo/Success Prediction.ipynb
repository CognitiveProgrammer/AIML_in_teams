# %% [markdown]
# ## It’s time to Welcome A.I. and Machine Learning into our Agile/Scrum teams and Ways of Working
#
# ### DEMO - 2: Predicting the Success of a Project
#
# <br/><br/><br/>
# ___A DEMO of predicting about the success of the project___

# %% [markdown]
# <br/><br/>
# ___Whatever success means to the organization___
# <br/><br/>

# %% [markdown]
# <br/><br/><br/>
#
# ___Let's first see the data we have with us___
#
# ___disclaimer: The Data is Random___
#
# <br/><br/><br/>

# %% [markdown]
# <br/><br/><br/>
#
# ___Now, let's train our M.L for the above mentioned Data___
#
# <br/><br/><br/>

# %%
import pandas as pd
import numpy as np
from sklearn import tree

# %%
df = pd.read_csv('decision_details.csv')

# %%
df
# Out:
#     sales_to_dev_start  prototype  cust_repr_onsite  num_team  leadership_of  \
# 0                    2          1                 1         3              1
# 1                    1          0                 0        10              2
# 2                    1          1                 0        12              3
# 3                    3          0                 0        11              4
# 4                    5          1                 1        12              1
# 5                    2          0                 1         9              2
# 6                    3          1                 1         2              3
# 7                    1          0                 1         8              4
# 8                    1          1                 0         5              4
# 9                    1          0                 0         4              1
# 10                  11          0                 0         6              2
# 11                  14          0                 0         7              3
# 12                   7          1                 0         8              4
# 13                   7          1                 1        10              1
# 14                   8          1                 1        15              2
# 15                   9          1                 1        12              3
# 16                  11          1                 1         1              4
# 17                   3          0                 0         1              1
# 18                   3          1                 0         4              2
# 19                   2          1                 0        11              3
# 20                   9          1                 1        12              4
#
#     multi_site  estimates_at  success_factor
# 0            1            40               1
# 1            0           100               0
# 2            1            25               0
# 3            1           140               1
# 4            1           130               1
# 5            1           120               0
# 6            0            74               0
# 7            0            32               1
# 8            0            11               1
# 9            1            24               0
# 10           0            32               1
# 11           1            55               1
# 12           0            42               0
# 13           1            34               1
# 14           0            23               0
# 15           1            29               1
# 16           1            11               1
# 17           0            12               1
# 18           0             9               1
# 19           1             2               0
# 20           0            84               0

# %%
X = df.drop('success_factor', axis=1)
y = df['success_factor']

# %%
model = tree.DecisionTreeClassifier()

# %%
model.fit(X,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %% [markdown]
# <br/><br/><br/><br/><br/>
#
# ___The training is completed, so now let's check the decisions we made for our future work___
#
# <br/><br/><br/>

# %%
sales_to_dev_start = 20
prototype = 0
cust_repr_onsite = 0
num_team = 5
leadership_of = 3
multi_site = 1
estimates_at = 100

predict_success_factor_for = np.array([sales_to_dev_start, prototype, cust_repr_onsite, 
                                       num_team, leadership_of, multi_site,estimates_at ])

# %% [markdown]
# <br/><br/><br/>
#
# ___Let's see what our prediction algorithm gives___
#
# <br/><br/><br/>

# %%
y_predict = model.predict([predict_success_factor_for])

# %%
y_predict
# Out:
# array([0])

# %% [markdown]
# ___1 :=> Success  ||   0 :=> Failure___
